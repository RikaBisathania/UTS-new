# %% [markdown]
# ### MASUKKAN KODE UNTUK PEMANGGILKAN DATA YANG AKAN DIPROSES

# %%
import pandas as pd
data_gaji = pd.read_csv('https://raw.githubusercontent.com/imdwipayana/DATA/main/Dataset%20Final%20Project%202023/Gaji/gaji.csv')
print (data_gaji)
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %% [markdown]
# ### MEMANGGIL 5 DATA PERTAMA

# %%
data_gaji.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  salary
# 0          2174             0              40   United-States   <=50K
# ...

# %% [markdown]
# ### MENGETAHUI JUMLAH BARIS DAN KOLOM DATA

# %%
data_gaji.shape
# Out:
# (32561, 15)

# %% [markdown]
# ### MENGETAHUI JENIS DATA PADA SETIAP KOLOMNYA

# %%
data_gaji.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# salary            object
# dtype: object

# %% [markdown]
# ### MENGETAHUI APAKAH PADA SETIAP KOLOM TERDAPAT DATA YANG KOSONG ATAU TIDAK

# %%
data_gaji.isnull().sum()

#Jika terdapat kolom yang datanya tidak kosong, maka harus dilakukan drop
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %% [markdown]
# ##### MEMBUAT DUMMY PADA DATA

# %%
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ### MENGGANTI DATA YANG BERUPA STRING MENJADI BERBENTUK NUMERIK

# %% [markdown]
# ###### Mengganti kolom workclass menjadi data numerik

# %%
data_gaji.workclass.unique()

#Kode untuk mengetahui data apa saja yang terdapat pada kolom workclass
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
#Mengganti data yang berupa string menjadi berbentu numerik
data_gaji['workclass'] = \
data_gaji['workclass'].map({' State-gov':0,' Self-emp-not-inc':1,' Private':2,' Federal-gov':3,' Local-gov':4,' ?':5, ' Self-emp-inc':6, ' Without-pay':7, ' Never-worked':8})

# %%
data_gaji.head()
#Tampilkan data yang
# Out:
#    age  workclass  fnlwgt   education  education-num       marital-status  \
# 0   39          0   77516   Bachelors             13        Never-married
# 1   50          1   83311   Bachelors             13   Married-civ-spouse
# 2   38          2  215646     HS-grad              9             Divorced
# 3   53          2  234721        11th              7   Married-civ-spouse
# 4   28          2  338409   Bachelors             13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capital-gain  \
# 0        Adm-clerical   Not-in-family   White     Male          2174
# 1     Exec-managerial         Husband   White     Male             0
# 2   Handlers-cleaners   Not-in-family   White     Male             0
# 3   Handlers-cleaners         Husband   Black     Male             0
# 4      Prof-specialty            Wife   Black   Female             0
#
#    capital-loss  hours-per-week  native-country  salary
# ...

# %% [markdown]
# ###### Mengganti kolom education menjadi data numerik

# %%
data_gaji.education.unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#        ' Preschool', ' 12th'], dtype=object)

# %%
data_gaji['education'] = \
data_gaji['education'].map({' Bachelors':0,' HS-grad':1,' 11th':2,' Masters':3,' 9th':4,' Some-college':5, ' Assoc-acdm':6, ' Assoc-voc':7, ' 7th-8th':8, ' Doctorate':9,' Prof-school':10, ' 5th-6th':11, ' 10th':12, ' 1st-4th':13, ' Preschool':14, ' 12th':15 })

# %%
data_gaji.head()
# Out:
#    age  workclass  fnlwgt  education  education-num       marital-status  \
# 0   39          0   77516          0             13        Never-married
# 1   50          1   83311          0             13   Married-civ-spouse
# 2   38          2  215646          1              9             Divorced
# 3   53          2  234721          2              7   Married-civ-spouse
# 4   28          2  338409          0             13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capital-gain  \
# 0        Adm-clerical   Not-in-family   White     Male          2174
# 1     Exec-managerial         Husband   White     Male             0
# 2   Handlers-cleaners   Not-in-family   White     Male             0
# 3   Handlers-cleaners         Husband   Black     Male             0
# 4      Prof-specialty            Wife   Black   Female             0
#
#    capital-loss  hours-per-week  native-country  salary
# ...

# %% [markdown]
# ###### Mengganti kolom salary menjadi data numerik

# %%
data_gaji.salary.unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
data_gaji['salary'] = \
data_gaji['salary'].map({' <=50K':0,' >50K':1})

# %%
data_gaji.head(40)
# Out:
#     age  workclass  fnlwgt  education  education-num          marital-status  \
# 0    39          0   77516          0             13           Never-married
# 1    50          1   83311          0             13      Married-civ-spouse
# 2    38          2  215646          1              9                Divorced
# 3    53          2  234721          2              7      Married-civ-spouse
# 4    28          2  338409          0             13      Married-civ-spouse
# 5    37          2  284582          3             14      Married-civ-spouse
# 6    49          2  160187          4              5   Married-spouse-absent
# 7    52          1  209642          1              9      Married-civ-spouse
# 8    31          2   45781          3             14           Never-married
# 9    42          2  159449          0             13      Married-civ-spouse
# 10   37          2  280464          5             10      Married-civ-spouse
# ...

# %% [markdown]
# ###### Mengganti kolom marital-status menjadi numerik

# %%
data_gaji['marital-status'].unique()

#Gunakan [] agar komputer tidak memproses data ini sebagai material dikurangi(-) status
# Out:
# array([' Never-married', ' Married-civ-spouse', ' Divorced',
#        ' Married-spouse-absent', ' Separated', ' Married-AF-spouse',
#        ' Widowed'], dtype=object)

# %%
data_gaji['marital-status'] = \
data_gaji['marital-status'].map({' Never-married':0,' Married-civ-spouse':1, ' Divorced':2, ' Married-spouse-absent':3, ' Separated':4, ' Married-AF-spouse':5, ' Widowed':6,})

# %%
data_gaji.head()
# Out:
#    age  workclass  fnlwgt  education  education-num  marital-status  \
# 0   39          0   77516          0             13               0
# 1   50          1   83311          0             13               1
# 2   38          2  215646          1              9               2
# 3   53          2  234721          2              7               1
# 4   28          2  338409          0             13               1
#
#            occupation    relationship    race      sex  capital-gain  \
# 0        Adm-clerical   Not-in-family   White     Male          2174
# 1     Exec-managerial         Husband   White     Male             0
# 2   Handlers-cleaners   Not-in-family   White     Male             0
# 3   Handlers-cleaners         Husband   Black     Male             0
# 4      Prof-specialty            Wife   Black   Female             0
#
#    capital-loss  hours-per-week  native-country  salary
# 0             0              40   United-States       0
# ...

# %% [markdown]
# ###### Mengganti kolom occupation menjadi numerik

# %%
data_gaji.occupation.unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' ?', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
data_gaji['occupation'] = \
data_gaji['occupation'].map({' Adm-clerical':0,' Exec-managerial':1, ' Handlers-cleaners':2, ' Prof-specialty':3, ' Other-service':4, ' Sales':5, ' Craft-repair':6, ' Transport-moving':7, ' Farming-fishing':8, ' Machine-op-inspct':9, ' Tech-support':10, ' ?':11, ' Protective-serv':12, ' Armed-Forces':13, ' Priv-house-serv':14})

# %%
data_gaji.head()
# Out:
#    age  workclass  fnlwgt  education  education-num  marital-status  \
# 0   39          0   77516          0             13               0
# 1   50          1   83311          0             13               1
# 2   38          2  215646          1              9               2
# 3   53          2  234721          2              7               1
# 4   28          2  338409          0             13               1
#
#    occupation    relationship    race      sex  capital-gain  capital-loss  \
# 0           0   Not-in-family   White     Male          2174             0
# 1           1         Husband   White     Male             0             0
# 2           2   Not-in-family   White     Male             0             0
# 3           2         Husband   Black     Male             0             0
# 4           3            Wife   Black   Female             0             0
#
#    hours-per-week  native-country  salary
# 0              40   United-States       0
# ...

# %% [markdown]
# ###### Mengganti kolom relationship menjadi numerik

# %%
data_gaji.relationship.unique()
# Out:
# array([' Not-in-family', ' Husband', ' Wife', ' Own-child', ' Unmarried',
#        ' Other-relative'], dtype=object)

# %%
data_gaji['relationship'] = \
data_gaji['relationship'].map({' Not-in-family':0,' Husband':1, ' Wife':2, ' Own-child':3, ' Unmarried':4, ' Other-relative':5})

# %%
data_gaji.head()
# Out:
#    age  workclass  fnlwgt  education  education-num  marital-status  \
# 0   39          0   77516          0             13               0
# 1   50          1   83311          0             13               1
# 2   38          2  215646          1              9               2
# 3   53          2  234721          2              7               1
# 4   28          2  338409          0             13               1
#
#    occupation  relationship    race      sex  capital-gain  capital-loss  \
# 0           0             0   White     Male          2174             0
# 1           1             1   White     Male             0             0
# 2           2             0   White     Male             0             0
# 3           2             1   Black     Male             0             0
# 4           3             2   Black   Female             0             0
#
#    hours-per-week  native-country  salary
# 0              40   United-States       0
# ...

# %% [markdown]
# ###### Mengganti kolom race menjadi numerik

# %%
data_gaji.race.unique()
# Out:
# array([' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo',
#        ' Other'], dtype=object)

# %%
data_gaji['race'] = \
data_gaji['race'].map({' White':0,' Black':1, ' Asian-Pac-Islander':2, ' Amer-Indian-Eskimo':3, ' Other':4})

# %%
data_gaji.head()
# Out:
#    age  workclass  fnlwgt  education  education-num  marital-status  \
# 0   39          0   77516          0             13               0
# 1   50          1   83311          0             13               1
# 2   38          2  215646          1              9               2
# 3   53          2  234721          2              7               1
# 4   28          2  338409          0             13               1
#
#    occupation  relationship  race      sex  capital-gain  capital-loss  \
# 0           0             0     0     Male          2174             0
# 1           1             1     0     Male             0             0
# 2           2             0     0     Male             0             0
# 3           2             1     1     Male             0             0
# 4           3             2     1   Female             0             0
#
#    hours-per-week  native-country  salary
# 0              40   United-States       0
# 1              13   United-States       0
# ...

# %% [markdown]
# ###### Mengganti kolom  native-country menjadi numerik

# %%
data_gaji['native-country'].unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' ?', ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
data_gaji['native-country'] = \
data_gaji['native-country'].map({' United-States':0, ' Cuba':1, ' Jamaica':2, ' India':3, ' ?':4, ' Mexico':5,
       ' South':6, ' Puerto-Rico':7, ' Honduras':8, ' England':9, ' Canada':10,
       ' Germany':11, ' Iran':12, ' Philippines':13, ' Italy':14, ' Poland':15,
       ' Columbia':16, ' Cambodia':17, ' Thailand':18, ' Ecuador':19, ' Laos':20,
       ' Taiwan':21, ' Haiti':22, ' Portugal':23, ' Dominican-Republic':24,
       ' El-Salvador':25, ' France':26, ' Guatemala':27, ' China':28, ' Japan':29,
       ' Yugoslavia':30, ' Peru':31, ' Outlying-US(Guam-USVI-etc)':32, ' Scotland':33,
       ' Trinadad&Tobago':34, ' Greece':35, ' Nicaragua':36, ' Vietnam':37, ' Hong':38,
       ' Ireland':39, ' Hungary':40, ' Holand-Netherlands':41})

# %%
data_gaji.head()
# Out:
#    age  workclass  fnlwgt  education  education-num  marital-status  \
# 0   39          0   77516          0             13               0
# 1   50          1   83311          0             13               1
# 2   38          2  215646          1              9               2
# 3   53          2  234721          2              7               1
# 4   28          2  338409          0             13               1
#
#    occupation  relationship  race      sex  capital-gain  capital-loss  \
# 0           0             0     0     Male          2174             0
# 1           1             1     0     Male             0             0
# 2           2             0     0     Male             0             0
# 3           2             1     1     Male             0             0
# 4           3             2     1   Female             0             0
#
#    hours-per-week  native-country  salary
# 0              40               0       0
# 1              13               0       0
# ...

# %% [markdown]
# ###### Mengganti kolom  sex menjadi numerik

# %%
data_gaji['sex'].unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %%
data_gaji['sex'] = \
data_gaji['sex'].map({' Male':0,' Female':1})

# %%
data_gaji.head()
# Out:
#    age  workclass  fnlwgt  education  education-num  marital-status  \
# 0   39          0   77516          0             13               0
# 1   50          1   83311          0             13               1
# 2   38          2  215646          1              9               2
# 3   53          2  234721          2              7               1
# 4   28          2  338409          0             13               1
#
#    occupation  relationship  race  sex  capital-gain  capital-loss  \
# 0           0             0     0    0          2174             0
# 1           1             1     0    0             0             0
# 2           2             0     0    0             0             0
# 3           2             1     1    0             0             0
# 4           3             2     1    1             0             0
#
#    hours-per-week  native-country  salary
# 0              40               0       0
# 1              13               0       0
# ...

# %%
data_gaji = pd.get_dummies(data_gaji)
data_gaji.head(40)
# Out:
#     age  workclass  fnlwgt  education  education-num  marital-status  \
# 0    39          0   77516          0             13               0
# 1    50          1   83311          0             13               1
# 2    38          2  215646          1              9               2
# 3    53          2  234721          2              7               1
# 4    28          2  338409          0             13               1
# 5    37          2  284582          3             14               1
# 6    49          2  160187          4              5               3
# 7    52          1  209642          1              9               1
# 8    31          2   45781          3             14               0
# 9    42          2  159449          0             13               1
# 10   37          2  280464          5             10               1
# 11   30          0  141297          0             13               1
# 12   23          2  122272          0             13               0
# ...

# %%
data_gaji.shape
# Out:
# (32561, 15)

# %%
data_gaji['salary'].value_counts()
# Out:
# 0    24720
# 1     7841
# Name: salary, dtype: int64

# %%
X = data_gaji.drop(['salary'],axis=1)
y = data_gaji['salary']

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
from sklearn import svm
model_svm = svm.SVC()

# %%
model_svm.fit(X_train, y_train)
# Out:
# SVC()

# %%
model_svm.score(X_test,y_test)
# Out:
# 0.7982496545370796

# %%
data_gaji.describe()
# Out:
#                 age     workclass        fnlwgt     education  education-num  \
# count  32561.000000  32561.000000  3.256100e+04  32561.000000   32561.000000
# mean      38.581647      2.309972  1.897784e+05      3.424465      10.080679
# std       13.640433      1.225728  1.055500e+05      3.453582       2.572720
# min       17.000000      0.000000  1.228500e+04      0.000000       1.000000
# 25%       28.000000      2.000000  1.178270e+05      1.000000       9.000000
# 50%       37.000000      2.000000  1.783560e+05      2.000000      10.000000
# 75%       48.000000      2.000000  2.370510e+05      5.000000      12.000000
# max       90.000000      8.000000  1.484705e+06     15.000000      16.000000
#
#        marital-status    occupation  relationship          race           sex  \
# count    32561.000000  32561.000000  32561.000000  32561.000000  32561.000000
# mean         1.083781      4.666411      1.542397      0.221707      0.330795
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.relplot(x='age', y='salary', data=data_gaji)
plt.show()

#Data ini tidak bisa menggunakan histogram karena merupakan data biner 
#Dot nya bertumpuk karena jumlah data yang sangat banyak

# %%
import seaborn as sns
sns.countplot(y=data_gaji["relationship"], hue=data_gaji["relationship"])
plt.show()
sns.countplot(y=data_gaji["education-num"], hue=data_gaji["education-num"])
plt.show()
sns.countplot(y=data_gaji["occupation"], hue=data_gaji["occupation"])
plt.show()

# %%
# Import library NumPy dan SciPy
import numpy as np
from scipy import stats

# Menghitung rata-rata, median, dan modus dari data gaji
mean = np.mean(data_gaji['salary'])
median = np.median(data_gaji['salary'])
mode = stats.mode(data_gaji['salary'])

# Menampilkan hasil analisis
print('Rata-rata: ', mean)
print('Median: ', median)
print('Modus: ', mode)
# Out:
# Rata-rata:  0.2408095574460244
# Median:  0.0
# Modus:  ModeResult(mode=array([0], dtype=int64), count=array([24720]))
# C:\Users\user\AppData\Local\Temp\ipykernel_12536\1874339352.py:8: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode = stats.mode(data_gaji['salary'])
